# %%
import numpy as np
import pandas as pd
import openpyxl
import os
from openpyxl import Workbook

# %%
def extract_information_from_last_non_empty_row(file_path, column_index):
    try:
        # Load the Excel workbook
        workbook = openpyxl.load_workbook(file_path)
        
        # Assuming the data is in the first sheet, you can change the sheet name if needed
        sheet = workbook.active
        
        # Get the last row in the sheet
        last_row = sheet.max_row
        
        # Find the last non-empty value in the specified column
        last_non_empty_value = None
        for row in range(17, last_row):
            value = sheet.cell(row=row, column=column_index).value
            if value is None:
                row = row - 1
                value = sheet.cell(row=row, column=column_index).value
                last_non_empty_value = value
                break
        
        # If a non-empty value is found, extract the entire row
        if last_non_empty_value is not None:
            cont_N = sheet.cell(row=4, column=4).value
            Le_name = sheet.cell(row=6, column=4).value
            last_row_data = [sheet.cell(row=row, column=col).value for col in range(2, sheet.max_column + 1)]
            return cont_N, Le_name, last_row_data
        else:
            return None
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def collect_excel_files(folder_path):
    # Get a list of all files in the folder
    all_files = os.listdir(folder_path)

    # Filter only Excel files (assuming .xlsx extension)
    excel_files = [file for file in all_files if file.endswith('.xlsx')]

    return excel_files

# %%
# Call Header
file_path = r"C:\Pam\Mitsu\encrypted_files (1)\ (1).xlsx"
workbook = openpyxl.load_workbook(file_path)
sheet = workbook.active
headers = ["Contract Number"] + ["Lease Name"] + [sheet.cell(row=17, column=col).value for col in range(2, sheet.max_column + 1)]  # Adjust the range as needed

# Specify the folder path
folder_path = r"C:\Pam\Mitsu\Payment Mitsubishi\20231213"

# Collect Excel files in the folder
input_file_paths = [os.path.join(folder_path, file) for file in collect_excel_files(folder_path)]
column_index = 5  # Column E
output_file_path = r"C:\Pam\Mitsu\20231213_mitsu_payment.xlsx"

# %%
# Create a new workbook for the output file
output_workbook = openpyxl.Workbook()
output_sheet = output_workbook.active

# Write headers to the output sheet
#headers = ["Contract Number"] + [sheet.cell(row=17, column=col).value for col in range(2, sheet.max_column + 1)]  # Adjust the range as needed
output_sheet.append(["File Name"] + headers)

# Iterate through input files and extract information
for file_path in input_file_paths:
    result = extract_information_from_last_non_empty_row(file_path, column_index)
    if result is not None:
        cont_N, Le_name, row_data = result
        # Append data to the output sheet
        output_sheet.append([os.path.basename(file_path)] + [cont_N] + [Le_name] + row_data)

# Save the output workbook
output_workbook.save(output_file_path)

# %%
input_file_paths
# Out:
# ['C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\1-ROYAL QUALITY ENTERPRISE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\10-GOOD-PRINT PRINTING LTD.,PART.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\100._KJ SOLUTION AND LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\101._KJ SOLUTION AND LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\102._PRATHUMCHAI LOGISTICS CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\103._PRATHUMCHAI LOGISTICS CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\104._THEPMONGKHOL SUKHOTHAI 2531 LTD.,PART..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\105._THEPMONGKHOL SUKHOTHAI 2531 LTD.,PART..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\106._THEPMONGKHOL SUKHOTHAI 2531 LTD.,PART..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\107 SAN(X)FA LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\108 GRAND BUSINESS INN CO.,LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\109 SUPVEERAWAT CO.,LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\11-PHAYA PRINTING AND PUBLISHING COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\110 FAMOUS TOUR CENTER CO.,LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\111 CENTRAN INTERNATIONAL.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\112 TONSAGRAPHIC & FRAME CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\113 SIRIKUL LAND & HOUSE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\114 NINNAT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\115 BUSINESS BRIDGE INTERNATIONAL CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\116-BENZ WONGSAWANG COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\117-BENZ WONGSAWANG COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\118 CHANG PHUM IMPORT- EXPORT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\119_CHAROENDEE KARNSURA 2005 CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\12-TAKAYAMA PRECISION  CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\120_CHAROENDEE KARNSURA 2005 CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\121_ADVANCEMENT INNOVATION MAINTENANCE SERVICE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\122_ADL LOGISTICS SERVICE COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\123_ADL LOGISTICS SERVICE COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\124_GREENPINE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\125_GREENPINE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\126_POWER GROW SERVICE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\127_KORAKIT TRANSPORT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\128_SITTHIPORN TRANSPORT(2016) LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\129_CHORTHAWEECHOKE CONSTRUCTION REGISTERED ORDINARY PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\13-SIAMVISION TRANSPORT CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\14-AJ CONTAINER CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\15-AJ CONTAINER CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\16-PLAMA TRANSPORT CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\17-DESTINATION RESORTS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\18-THANSETTAKIJ CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\19-THANSETTAKIJ CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\2-DIATEC WORK COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\20-NAS 216 CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\21-TIGER AUTOCAR CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\22-Smart Traffic Co  Ltd.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\23-AP PARKING CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\24-O.T DESIGN KHONKAEN CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\25-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\26._THE NEW CONCEPT PROPERTY CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\27-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\28-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\29-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\3-TAKAYAMA PRECISION  CO.LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\30-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\31-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\32-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\33-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\34-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\35-THE NEW CONCEPT PROPERTY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\36-R.S.P.C. SUPPLY CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\37-NAKHON LUNG LENS CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\38-TC Advertising Media Co Ltd.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\39-TAKKOB 4152 INKJET CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\4._K.S.N. PRECISION TOOLS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\40-Groovy Map Co Ltd.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\41-THE TREE AGROTECH (THAILAND) CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\42-TORINE CO LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\43-THE NEW CONCEPT PERFECT RESIDENCE 1 COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\44-Medical Worldtech Company Limited.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\45._FINGERPRINT GRAND CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\46._GRAPHIC ART AND DESIGN COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\47._THE NEW CONCEPT ASSET MANAGEMENT.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\48._SEATRANS MULTIMODAL TRANSPORT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\49._TANAVANIT YOUR CONSULT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\5-K.S.N. PRECISION TOOLS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\50._CHAINAT RUBBER CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\51._GOOD-WILL BANGKOK GROUP CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\52._TDC AGENCY COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\53._Triple i Maritime Agencies Co., Ltd..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\54._SEA SUN SAND COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\55._MULTI INFINITY CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\56._SPM GROUP SERVICE COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\57._FRINT CREATION AND DESIGN LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\58._MORERICH MANAGEMENT (THAILAND) CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\59._IDEE EXCELLENT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\6-K.S.N. PRECISION TOOLS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\60._RPV VALUATION CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\61._RPV VALUATION CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\62._MR.PERFECT HOME CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\63._FASTER NEW CORPORATION CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\64._PARADEE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\65._P. THONGCHOO SERVICES LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\66._TAWANAUX GRAPHICDESIGNS.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\67._SMART COATING AND SERVICES CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\68._CHIANGMAI HAPPY TOUR CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\69._POWERLAND PLUS APPRAISAL CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\7 -CHPI ENGINEERING (THAILAND)CO.LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\70._ACCESS & ASSOCIATES CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\71._EN TO EN INTERMOLD CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\72._AI PRECISION PART COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\73._P.S.T.RUNG RUEANG TRANSPORT LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\74._TEN MOLD SUPPLY & SERVICE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\75._TEN MOLD SUPPLY & SERVICE CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\76._KORAKIT TRANSPORT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\77._PAPHANGKORN PETROLEUM CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\78._LADDA TRANSPORT AND SUPPLY CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\79._PHITNICHA TRANSPORT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\8-CHPI ENGINEERING (THAILAND) CO.LTD.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\80._PHITNICHA TRANSPORT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\81._PHITNICHA TRANSPORT CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\82._CHANTICHA TRANSPORT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\83._CHANTICHA TRANSPORT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\84._CHANTICHA TRANSPORT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\85._CHANTICHA TRANSPORT COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\86._PDL LOGISTICS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\87._PDL LOGISTICS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\88._PDL LOGISTICS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\89._PDL LOGISTICS LIMITED PARTNERSHIP.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\9-AW TOOLS AND AUTOMATION COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\90._SUBSOMJAI AND PE LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\91._SUBSOMJAI AND PE LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\92_SUBSOMJAI AND PE LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\93._SUBSOMJAI AND PE LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\94._CHOK CHAROEN CHAI LOGISTICS COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\95._THAI ORIENTAL HOLIDAY CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\96._THAI ORIENTAL HOLIDAY CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\97._THAI ORIENTAL HOLIDAY CO.,LTD..xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\98._PHUTTHARAKSA LABOR COMPANY LIMITED.xlsx',
#  'C:\\Pam\\Mitsu\\Payment Mitsubishi\\20231213\\99._PHUTTHARAKSA LABOR COMPANY LIMITED.xlsx']
